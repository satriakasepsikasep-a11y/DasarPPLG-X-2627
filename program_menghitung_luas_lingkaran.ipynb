# %% [markdown]
# <a href="https://colab.research.google.com/github/satriakasepsikasep-a11y/DasarPPLG-X-2627/blob/main/program_menghitung_luas_lingkaran.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TUGAS MEMBUAT MENGHITUNG BANGUN DATAR LUAS LINGKARAN
#
# nama kelompok : IQ+KETENANGAN
# 1.Rafa Anurwansyah
# 2.Syafiq Hakim
# 3.Satria Aprilliansyah
# 4.Fiqih Ramadhan

# %%
! g++ --version
# Out:
# g++ (Ubuntu 13.3.0-6ubuntu2~24.04.1) 13.3.0
# Copyright (C) 2023 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# %%writefile luas_lingkaran.cpp
# #include <iostream>
# using namespace std;
#
# int main()
# {
#     float jari_jari, luas;
#     float phi = 3.14;
#
#     cout << "Program Aplikasi Menghitung Luas Lingkaran" << endl;
#     cout << "Masukkan jari-jari: ";
#     cin >> jari_jari;
#
#     luas = phi * jari_jari * jari_jari;
#
#     cout << "Luas lingkaran = " << luas << endl;
#
#     return 0;
# }
# Out:
# Overwriting luas_lingkaran.cpp

# %%
# !g++ luas_lingkaran.cpp -o main

# %%
# !./main
# Out:
# Program Aplikasi Menghitung Luas Lingkaran
# Masukkan jari-jari: 20
# Luas lingkaran = 1256
