# %% [markdown]
# <a href="https://colab.research.google.com/github/satriakasepsikasep-a11y/DasarPPLG-X-2627/blob/main/X_PPLG_SatriaAprilliansyah_Tugas1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile input_data.cpp
# #include <iostream>
# #include <string>
# using namespace std;
#
# int main() {
#     string namaSiswa;
#     int umur;
#
#     cout << "satria (1 Kata) : ";
#     cin >> namaSiswa;
#
#     cout << "16     : ";
#     cin >> umur;
#
#     cout << "\nHalo " << namaSiswa << ", ternyata umur kamu " << umur << " 16 tahun ya!" << endl;
#     return 0;
# }
# Out:
# Overwriting input_data.cpp

# %%
# !g++ input_data.cpp -o input_data

# %%
# !./input_data
# Out:
# satria (1 Kata) : satria
# 16     : 16
#
# Halo satria, ternyata umur kamu 16 16 tahun ya!
